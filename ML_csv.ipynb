# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

train_df=pd.read_csv("/content/drive/MyDrive/MetaData/train.csv") #reading the data from the var
train_df
# Out:
#          image_name  patient_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968    male        45.0
# 1      ISIC_0015719  IP_3075186  female        45.0
# 2      ISIC_0052212  IP_2842074  female        50.0
# 3      ISIC_0068279  IP_6890425  female        45.0
# 4      ISIC_0074268  IP_8723313  female        55.0
# ...             ...         ...     ...         ...
# 33121  ISIC_9999134  IP_6526534    male        50.0
# 33122  ISIC_9999320  IP_3650745    male        65.0
# 33123  ISIC_9999515  IP_2026598    male        20.0
# 33124  ISIC_9999666  IP_7702038    male        50.0
# 33125  ISIC_9999806  IP_0046310    male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target
# 0                         head/neck   unknown           benign       0
# 1                   upper extremity   unknown           benign       0
# 2                   lower extremity     nevus           benign       0
# 3                         head/neck   unknown           benign       0
# 4                   upper extremity   unknown           benign       0
# ...                             ...       ...              ...     ...
# 33121                         torso   unknown           benign       0
# 33122                         torso   unknown           benign       0
# 33123               lower extremity   unknown           benign       0
# 33124               lower extremity   unknown           benign       0
# 33125                         torso     nevus           benign       0
#
# [33126 rows x 8 columns]

# %% [markdown]
# בדיקה מה מיוחד בכל עמודה:

# %%
print(train_df.columns)
print(pd.unique(train_df.sex))
print(pd.unique(train_df.age_approx))
print(pd.unique(train_df.anatom_site_general_challenge))
print(pd.unique(train_df.diagnosis))
print(pd.unique(train_df.benign_malignant))
print(pd.unique(train_df.target))
# Out:
# Index(['image_name', 'patient_id', 'sex', 'age_approx',
#        'anatom_site_general_challenge', 'diagnosis', 'benign_malignant',
#        'target'],
#       dtype='object')
# ['male' 'female' nan]
# [45. 50. 55. 40. 25. 35. 30. 75. 70. 65. 60. nan 80. 20. 85. 15. 90. 10.
#   0.]
# ['head/neck' 'upper extremity' 'lower extremity' 'torso' nan 'palms/soles'
#  'oral/genital']
# ['unknown' 'nevus' 'melanoma' 'seborrheic keratosis' 'lentigo NOS'
#  'lichenoid keratosis' 'solar lentigo' 'cafe-au-lait macule'
#  'atypical melanocytic proliferation']
# ['benign' 'malignant']
# [0 1]

# %%
train_df.dropna()
# Out:
#          image_name  patient_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968    male        45.0
# 1      ISIC_0015719  IP_3075186  female        45.0
# 2      ISIC_0052212  IP_2842074  female        50.0
# 3      ISIC_0068279  IP_6890425  female        45.0
# 4      ISIC_0074268  IP_8723313  female        55.0
# ...             ...         ...     ...         ...
# 33121  ISIC_9999134  IP_6526534    male        50.0
# 33122  ISIC_9999320  IP_3650745    male        65.0
# 33123  ISIC_9999515  IP_2026598    male        20.0
# 33124  ISIC_9999666  IP_7702038    male        50.0
# 33125  ISIC_9999806  IP_0046310    male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target
# 0                         head/neck   unknown           benign       0
# 1                   upper extremity   unknown           benign       0
# 2                   lower extremity     nevus           benign       0
# 3                         head/neck   unknown           benign       0
# 4                   upper extremity   unknown           benign       0
# ...                             ...       ...              ...     ...
# 33121                         torso   unknown           benign       0
# 33122                         torso   unknown           benign       0
# 33123               lower extremity   unknown           benign       0
# 33124               lower extremity   unknown           benign       0
# 33125                         torso     nevus           benign       0
#
# [32531 rows x 8 columns]

# %%
#train_df = train_df.set_index('image_name')

# Remove patient_id column and save in a new DataFrame
df_for_prediction = train_df.drop('patient_id', axis=1)

# Perform one-hot encoding
one_hot_encoded = pd.get_dummies(df_for_prediction[['sex', 'anatom_site_general_challenge']])

df_for_prediction = pd.concat([one_hot_encoded, df_for_prediction[['age_approx', 'target']]], axis=1)

# %%
df_for_prediction = df_for_prediction[~df_for_prediction.astype(str).eq('nan').any(axis=1)]
df_for_prediction
# Out:
#        sex_female  sex_male  anatom_site_general_challenge_head/neck  \
# 0               0         1                                        1
# 1               1         0                                        0
# 2               1         0                                        0
# 3               1         0                                        1
# 4               1         0                                        0
# ...           ...       ...                                      ...
# 33121           0         1                                        0
# 33122           0         1                                        0
# 33123           0         1                                        0
# 33124           0         1                                        0
# 33125           0         1                                        0
#
#        anatom_site_general_challenge_lower extremity  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 33121                                              0
# 33122                                              0
# 33123                                              1
# 33124                                              1
# 33125                                              0
#
#        anatom_site_general_challenge_oral/genital  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 33121                                           0
# 33122                                           0
# 33123                                           0
# 33124                                           0
# 33125                                           0
#
#        anatom_site_general_challenge_palms/soles  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 33121                                          0
# 33122                                          0
# 33123                                          0
# 33124                                          0
# 33125                                          0
#
#        anatom_site_general_challenge_torso  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 33121                                    1
# 33122                                    1
# 33123                                    0
# 33124                                    0
# 33125                                    1
#
#        anatom_site_general_challenge_upper extremity  age_approx  target
# 0                                                  0        45.0       0
# 1                                                  1        45.0       0
# 2                                                  0        50.0       0
# 3                                                  0        45.0       0
# 4                                                  1        55.0       0
# ...                                              ...         ...     ...
# 33121                                              0        50.0       0
# 33122                                              0        65.0       0
# 33123                                              0        20.0       0
# 33124                                              0        50.0       0
# 33125                                              0        45.0       0
#
# [33058 rows x 10 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import seaborn as sns
from sklearn.ensemble import AdaBoostClassifier

# %%
X = df_for_prediction.iloc[:,0:-1]
Y = df_for_prediction['target']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=0, stratify=Y)

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have X_train, Y_train, X_test, Y_test defined

classifiers = [
    RandomForestClassifier(n_estimators=50, random_state=0),
    AdaBoostClassifier(n_estimators=50, random_state=0)
]

for clf in classifiers:
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    
    accuracy = accuracy_score(Y_test, Y_pred)
    auc_score = roc_auc_score(Y_test, Y_pred)
    cm = confusion_matrix(Y_test, Y_pred)
    
    print("Accuracy D.T.:", accuracy)
    print("AUC:", auc_score)
    
    labels = ['0', '1']
    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()
# Out:
# Accuracy D.T.: 0.9824561403508771
# AUC: 0.5
# Accuracy D.T.: 0.9824561403508771
# AUC: 0.5

# %%
# clf_DT = DecisionTreeClassifier(max_depth=4)
# clf_DT.fit(X_train, Y_train)

# predictions = clf_DT.predict(X_test)
# predictions

# accuracy = accuracy_score(Y_test, predictions)
# print("Accuracy D.T.:", accuracy)
# auc_score = roc_auc_score(Y_test, predictions)
# print("AUC:", auc_score)

# cm = confusion_matrix(Y_test, predictions)
# labels = ['0', '1']
# plt.figure(figsize=(5, 5))
# sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(20, 5))
# plot_tree(clf_DT, feature_names=X.columns, class_names=clf_DT.classes_.astype(str), filled=True , fontsize=7)
# plt.show()

# %%
selected_df = df_for_prediction[df_for_prediction['target'] == 1].copy()
sampled_data = df_for_prediction[df_for_prediction['target'] == 0].sample(n=2000, random_state=42)
new_df = pd.concat([selected_df, sampled_data], ignore_index=True)

X = new_df.iloc[:,0:-1]
Y = new_df['target']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=0, stratify=Y)

# %%
clf = DecisionTreeClassifier(max_depth=4)
clf.fit(X_train, Y_train)

predictions = clf.predict(X_test)
predictions

accuracy = accuracy_score(Y_test, predictions)
print("Accuracy D.T.:", accuracy)
auc_score = roc_auc_score(Y_test, predictions)
print("AUC:", auc_score)

cm = confusion_matrix(Y_test, predictions)
labels = ['0', '1']
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

plt.figure(figsize=(15, 5))
plot_tree(clf, feature_names=X.columns, class_names=clf.classes_.astype(str), filled=True , fontsize=8)
plt.show()
# Out:
# Accuracy D.T.: 0.7644787644787645
# AUC: 0.5427966101694914

# %%
# X = df_for_prediction.iloc[:,0:-1]
# Y = df_for_prediction['target']

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=0, stratify=Y)

# %%
adaboost = AdaBoostClassifier(n_estimators=50, random_state=0)
adaboost.fit(X_train, Y_train)

Y_pred = adaboost.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy D.T.:", accuracy)
auc_score = roc_auc_score(Y_test, Y_pred)
print("AUC:", auc_score)

cm = confusion_matrix(Y_test, Y_pred)
labels = ['0', '1']
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy D.T.: 0.7606177606177607
# AUC: 0.5582203389830508

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Assuming you have already loaded your dataframe df_for_prediction

# Extract the features (X) and target (Y)
X = df_for_prediction.iloc[:, 0:-1]
Y = df_for_prediction['target']

# Perform K-means clustering with 3 clusters
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

# Get the predicted cluster labels for each sample
cluster_labels = kmeans.labels_

# Plotting the clusters
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=cluster_labels, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# קורלציה

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)
(df_for_prediction.corr()).style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_b367c_row0_col0, #T_b367c_row1_col1, #T_b367c_row2_col2, #T_b367c_row3_col3, #T_b367c_row4_col4, #T_b367c_row5_col5, #T_b367c_row6_col6, #T_b367c_row7_col7, #T_b367c_row8_col8, #T_b367c_row9_col9 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_b367c_row0_col1, #T_b367c_row0_col8, #T_b367c_row0_col9, #T_b367c_row1_col0, #T_b367c_row3_col6, #T_b367c_row6_col2, #T_b367c_row6_col3, #T_b367c_row6_col4, #T_b367c_row6_col5, #T_b367c_row6_col7 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_b367c_row0_col2, #T_b367c_row4_col2 {
#   background-color: #bfdebf;
#   color: #000000;
# }
# #T_b367c_row0_col3 {
#   background-color: #8bc48b;
#   color: #000000;
# }
# #T_b367c_row0_col4, #T_b367c_row2_col4 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_b367c_row0_col5, #T_b367c_row3_col2 {
#   background-color: #d7e9d7;
#   color: #000000;
# }
# #T_b367c_row0_col6 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_b367c_row0_col7, #T_b367c_row4_col6, #T_b367c_row5_col3 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_b367c_row1_col2 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_b367c_row1_col3 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_b367c_row1_col4 {
#   background-color: #daebda;
#   color: #000000;
# }
# #T_b367c_row1_col5, #T_b367c_row7_col2 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_b367c_row1_col6 {
#   background-color: #89c389;
#   color: #000000;
# }
# #T_b367c_row1_col7 {
#   background-color: #add5ad;
#   color: #000000;
# }
# #T_b367c_row1_col8 {
#   background-color: #bddcbd;
#   color: #000000;
# }
# #T_b367c_row1_col9, #T_b367c_row7_col5 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_b367c_row2_col0, #T_b367c_row5_col0 {
#   background-color: #78bb78;
#   color: #f1f1f1;
# }
# #T_b367c_row2_col1, #T_b367c_row5_col1 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_b367c_row2_col3, #T_b367c_row4_col7 {
#   background-color: #a8d2a8;
#   color: #000000;
# }
# #T_b367c_row2_col5 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_b367c_row2_col6 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_b367c_row2_col7 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_b367c_row2_col8 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_b367c_row2_col9, #T_b367c_row5_col8, #T_b367c_row8_col5 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_b367c_row3_col0, #T_b367c_row7_col0 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_b367c_row3_col1, #T_b367c_row7_col1 {
#   background-color: #7bbc7b;
#   color: #000000;
# }
# #T_b367c_row3_col4, #T_b367c_row5_col9 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_b367c_row3_col5, #T_b367c_row7_col9, #T_b367c_row8_col4 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_b367c_row3_col7 {
#   background-color: #cde5cd;
#   color: #000000;
# }
# #T_b367c_row3_col8 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_b367c_row3_col9 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_b367c_row4_col0 {
#   background-color: #77ba77;
#   color: #f1f1f1;
# }
# #T_b367c_row4_col1 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_b367c_row4_col3 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_b367c_row4_col5 {
#   background-color: #d5e9d5;
#   color: #000000;
# }
# #T_b367c_row4_col8 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_b367c_row4_col9, #T_b367c_row7_col4 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_b367c_row5_col2, #T_b367c_row9_col8 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_b367c_row5_col4 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_b367c_row5_col6 {
#   background-color: #a4d0a4;
#   color: #000000;
# }
# #T_b367c_row5_col7 {
#   background-color: #acd4ac;
#   color: #000000;
# }
# #T_b367c_row6_col0 {
#   background-color: #7dbd7d;
#   color: #000000;
# }
# #T_b367c_row6_col1 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_b367c_row6_col8, #T_b367c_row7_col8 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_b367c_row6_col9 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_b367c_row7_col3 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_b367c_row7_col6 {
#   background-color: #d3e7d3;
#   color: #000000;
# }
# #T_b367c_row8_col0 {
#   background-color: #83c083;
#   color: #000000;
# }
# #T_b367c_row8_col1 {
#   background-color: #68b368;
#   color: #f1f1f1;
# }
# #T_b367c_row8_col2 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_b367c_row8_col3 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_b367c_row8_col6, #T_b367c_row9_col3 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_b367c_row8_col7 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_b367c_row8_col9 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_b367c_row9_col0 {
#   background-color: #78bb78;
#   color: #000000;
# }
# #T_b367c_row9_col1 {
#   background-color: #72b872;
#   color: #f1f1f1;
# }
# #T_b367c_row9_col2 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_b367c_row9_col4 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_b367c_row9_col5 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_b367c_row9_col6 {
#   background-color: #96c996;
#   color: #000000;
# }
# #T_b367c_row9_col7 {
#   background-color: #a2cfa2;
#   color: #000000;
# }
# </style>
# <table id="T_b367c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b367c_level0_col0" class="col_heading level0 col0" >sex_female</th>
#       <th id="T_b367c_level0_col1" class="col_heading level0 col1" >sex_male</th>
#       <th id="T_b367c_level0_col2" class="col_heading level0 col2" >anatom_site_general_challenge_head/neck</th>
#       <th id="T_b367c_level0_col3" class="col_heading level0 col3" >anatom_site_general_challenge_lower extremity</th>
#       <th id="T_b367c_level0_col4" class="col_heading level0 col4" >anatom_site_general_challenge_oral/genital</th>
#       <th id="T_b367c_level0_col5" class="col_heading level0 col5" >anatom_site_general_challenge_palms/soles</th>
#       <th id="T_b367c_level0_col6" class="col_heading level0 col6" >anatom_site_general_challenge_torso</th>
#       <th id="T_b367c_level0_col7" class="col_heading level0 col7" >anatom_site_general_challenge_upper extremity</th>
#       <th id="T_b367c_level0_col8" class="col_heading level0 col8" >age_approx</th>
#       <th id="T_b367c_level0_col9" class="col_heading level0 col9" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b367c_level0_row0" class="row_heading level0 row0" >sex_female</th>
#       <td id="T_b367c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b367c_row0_col1" class="data row0 col1" >-1.000000</td>
#       <td id="T_b367c_row0_col2" class="data row0 col2" >-0.015755</td>
#       <td id="T_b367c_row0_col3" class="data row0 col3" >0.054159</td>
#       <td id="T_b367c_row0_col4" class="data row0 col4" >-0.014787</td>
#       <td id="T_b367c_row0_col5" class="data row0 col5" >-0.017291</td>
#       <td id="T_b367c_row0_col6" class="data row0 col6" >-0.066969</td>
#       <td id="T_b367c_row0_col7" class="data row0 col7" >0.048844</td>
#       <td id="T_b367c_row0_col8" class="data row0 col8" >-0.109827</td>
#       <td id="T_b367c_row0_col9" class="data row0 col9" >-0.028612</td>
#     </tr>
#     <tr>
#       <th id="T_b367c_level0_row1" class="row_heading level0 row1" >sex_male</th>
#       <td id="T_b367c_row1_col0" class="data row1 col0" >-1.000000</td>
#       <td id="T_b367c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b367c_row1_col2" class="data row1 col2" >0.015755</td>
#       <td id="T_b367c_row1_col3" class="data row1 col3" >-0.054159</td>
#       <td id="T_b367c_row1_col4" class="data row1 col4" >0.014787</td>
#       <td id="T_b367c_row1_col5" class="data row1 col5" >0.017291</td>
#       <td id="T_b367c_row1_col6" class="data row1 col6" >0.066969</td>
#       <td id="T_b367c_row1_col7" class="data row1 col7" >-0.048844</td>
#       <td id="T_b367c_row1_col8" class="data row1 col8" >0.109827</td>
#       <td id="T_b367c_row1_col9" class="data row1 col9" >0.028612</td>
#     </tr>
#     <tr>
#       <th id="T_b367c_level0_row2" class="row_heading level0 row2" >anatom_site_general_challenge_head/neck</th>
#       <

# %% [markdown]
# מידע על מטופלים ולא מידע על דוגמות

# %%
'''
train_df_1st_from_each = train_df.drop_duplicates('patient_id')
print(train_df_1st_from_each.shape)
'''
# Out:
# "\ntrain_df_1st_from_each = train_df.drop_duplicates('patient_id')\nprint(train_df_1st_from_each.shape)\n"

# %%
'''
one_id = [d for _, d in train_df.groupby('patient_id')]
one_id
'''
# Out:
# "\none_id = [d for _, d in train_df.groupby('patient_id')]\none_id\n"

# %% [markdown]
# **מכאן קוד של הילה**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

trainDf=pd.read_csv("/content/drive/MyDrive/MetaData/train.csv") #reading the data from the var

# %%
trainDf.head() #לראות איך הדטא מתקבל
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
trainDf["image_name"] = trainDf["image_name"].str.replace("ISIC_", "")
trainDf.head() #לראות איך הדטא מתקבל
# Out:
#   image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0    2637011  IP_7279968    male        45.0                     head/neck
# 1    0015719  IP_3075186  female        45.0               upper extremity
# 2    0052212  IP_2842074  female        50.0               lower extremity
# 3    0068279  IP_6890425  female        45.0                     head/neck
# 4    0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
trainDf.info() #מה מציגה כל עמודה ואם יש ערכים חסרים
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33126 entries, 0 to 33125
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   image_name                     33126 non-null  object
#  1   patient_id                     33126 non-null  object
#  2   sex                            33061 non-null  object
#  3   age_approx                     33058 non-null  float64
#  4   anatom_site_general_challenge  32599 non-null  object
#  5   diagnosis                      33126 non-null  object
#  6   benign_malignant               33126 non-null  object
#  7   target                         33126 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.0+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x = trainDf['target'].value_counts().values
sns.barplot(x = [0, 1], y = x, width = 0.5)
plt.title('Target Count')
plt.show() #מראה את יחס הטרגטים זה לזה

print(["benign","malignant"])
print(x)
# Out:
# ['benign', 'malignant']
# [32542   584]

# %% [markdown]
# the targets are imbalanced.
#
# we dont want the classifier to always predict the larger class in order to have a high accuracy rate, and have false-negative prediction. so we need to change the performance metric.

# %%
#train_df = train_df.set_index('image_name')

# Remove patient_id column and save in a new DataFrame
df_for_predict = trainDf.drop('patient_id', axis=1)

# Perform one-hot encoding
one_hot_encoded = pd.get_dummies(df_for_predict[['sex', 'anatom_site_general_challenge']])

df_for_predict = pd.concat([one_hot_encoded, df_for_predict[['age_approx', 'target']]], axis=1)

# %%
df_for_predict = df_for_predict[~df_for_predict.astype(str).eq('nan').any(axis=1)]
df_for_predict
# Out:
#        sex_female  sex_male  anatom_site_general_challenge_head/neck  \
# 0               0         1                                        1
# 1               1         0                                        0
# 2               1         0                                        0
# 3               1         0                                        1
# 4               1         0                                        0
# ...           ...       ...                                      ...
# 33121           0         1                                        0
# 33122           0         1                                        0
# 33123           0         1                                        0
# 33124           0         1                                        0
# 33125           0         1                                        0
#
#        anatom_site_general_challenge_lower extremity  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 33121                                              0
# 33122                                              0
# 33123                                              1
# 33124                                              1
# 33125                                              0
#
#        anatom_site_general_challenge_oral/genital  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 33121                                           0
# 33122                                           0
# 33123                                           0
# 33124                                           0
# 33125                                           0
#
#        anatom_site_general_challenge_palms/soles  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 33121                                          0
# 33122                                          0
# 33123                                          0
# 33124                                          0
# 33125                                          0
#
#        anatom_site_general_challenge_torso  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 33121                                    1
# 33122                                    1
# 33123                                    0
# 33124                                    0
# 33125                                    1
#
#        anatom_site_general_challenge_upper extremity  age_approx  target
# 0                                                  0        45.0       0
# 1                                                  1        45.0       0
# 2                                                  0        50.0       0
# 3                                                  0        45.0       0
# 4                                                  1        55.0       0
# ...                                              ...         ...     ...
# 33121                                              0        50.0       0
# 33122                                              0        65.0       0
# 33123                                              0        20.0       0
# 33124                                              0        50.0       0
# 33125                                              0        45.0       0
#
# [33058 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

#חלוקה לאימון וולידציה 80-20
X_train, X_test, y_train, y_test = train_test_split(df_for_predict.drop('target', axis=1), df_for_predict['target'], test_size=0.2, random_state=1)

# %% [markdown]
# now we will try resampling by removing samples from the majority class, and adding more examples from the minority class.
#
# we use the resampling module from Scikit-Learn to randomly replicate samples from the smaller class.

# %% [markdown]
# drawback is removing information that may be valuable. this could lead to underfitting and poor generalization to the test set.

# %%
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score,precision_recall_curve,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import time
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, TruncatedSVD

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import seaborn as sns
from sklearn.ensemble import AdaBoostClassifier

# %%
'''
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X_train, y_train)

# Separate input features and target
y = df_for_predict.target
X = df_for_predict.drop('target', axis=1)

# setting up testing and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)

oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

sm = SMOTE(random_state=27)
X_train, y_train = sm.fit_sample(X_train, y_train)
'''
#
'''
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
columns = X_train.columns
os_data_X, os_data_y = os.fit_resample(X_train, y_train)
'''
# Out:
# '\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)\ncolumns = X_train.columns\nos_data_X, os_data_y = os.fit_resample(X_train, y_train)\n'

# %%
''' רק לעכשיו!!!!!!!!!!!!!!!!!!!!!!!!!!!!
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Separate input features and target
y = df_for_predict.target
X = df_for_predict.drop('target', axis=1)

# Setting up testing and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)

sm = SMOTE(random_state=27)
X_train, y_train = sm.fit_resample(X_train, y_train)

# Continue with further analysis or modeling using the oversampled data
'''
# Out:
# " רק לעכשיו!!!!!!!!!!!!!!!!!!!!!!!!!!!!\nfrom imblearn.over_sampling import SMOTE\nfrom sklearn.model_selection import train_test_split\n\n# Separate input features and target\ny = df_for_predict.target\nX = df_for_predict.drop('target', axis=1)\n\n# Setting up testing and training sets\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)\n\nsm = SMOTE(random_state=27)\nX_train, y_train = sm.fit_resample(X_train, y_train)\n\n# Continue with further analysis or modeling using the oversampled data\n"

# %%
print(X.shape)
print(y.shape)

if X.shape[0] != y.shape[0]:
  print("X and y rows are mismatched, check dataset again")
# Out:
# (33058, 9)
# (33058,)

# %%
''' רק לעכשיו!!!!!!!!!!!!!!!!!!!!!!!
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Separate input features and target
y = df_for_predict.target
X = df_for_predict.drop('target', axis=1)

# Setting up testing and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)

sm = SMOTE(random_state=27)
X_train_resampled, y_train_resampled = sm.fit_resample(X_train, y_train)

# Continue with further analysis or modeling using the oversampled data

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have X_train_resampled, y_train_resampled, X_test, Y_test defined

classifiers = [
    RandomForestClassifier(n_estimators=50, random_state=0),
    AdaBoostClassifier(n_estimators=50, random_state=0)
]

for clf in classifiers:
    clf.fit(X_train_resampled, y_train_resampled)
    y_pred = clf.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    auc_score = roc_auc_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)
    
    print("Accuracy:", accuracy)
    print("AUC:", auc_score)
    
    labels = ['0', '1']
    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()
'''
# Out:
# ' רק לעכשיו!!!!!!!!!!!!!!!!!!!!!!!\nfrom imblearn.over_sampling import SMOTE\nfrom sklearn.model_selection import train_test_split\n\n# Separate input features and target\ny = df_for_predict.target\nX = df_for_predict.drop(\'target\', axis=1)\n\n# Setting up testing and training sets\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)\n\nsm = SMOTE(random_state=27)\nX_train_resampled, y_train_resampled = sm.fit_resample(X_train, y_train)\n\n# Continue with further analysis or modeling using the oversampled data\n\nfrom sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier\nfrom sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\n# Assuming you have X_train_resampled, y_train_resampled, X_test, Y_test defined\n\nclassifiers = [\n    RandomForestClassifier(n_estimators=50, random_state=0),\n    AdaBoostClassifier(n_estimators=50, random_state=0)\n]\n\nfor clf in classifiers:\n    clf.fit(X_train_resampled, y_train_resampled)\n    y_pred = clf.predict(X_test)\n    \n    accuracy = accuracy_score(y_test, y_pred)\n    auc_score = roc_auc_score(y_test, y_pred)\n    cm = confusion_matrix(y_test, y_pred)\n    \n    print("Accuracy:", accuracy)\n    print("AUC:", auc_score)\n    \n    labels = [\'0\', \'1\']\n    plt.figure(figsize=(5, 5))\n    sns.heatmap(cm, annot=True, cmap=\'Blues\', xticklabels=labels, yticklabels=labels)\n    plt.xlabel(\'Predicted\')\n    plt.ylabel(\'Actual\')\n    plt.title(\'Confusion Matrix\')\n    plt.show()\n'

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have X_train_resampled, y_train_resampled, X_test, y_test defined

# Define class weights
class_weights = dict(zip([0, 1], [(len(y_train_resampled) / (2 * np.bincount(y_train_resampled)))[0],
                                 (len(y_train_resampled) / (2 * np.bincount(y_train_resampled)))[1]]))

classifiers = [
    RandomForestClassifier(n_estimators=50, random_state=0, class_weight=class_weights),
    AdaBoostClassifier(n_estimators=50, random_state=0)
]

for clf in classifiers:
    clf.fit(X_train_resampled, y_train_resampled)
    y_pred = clf.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    auc_score = roc_auc_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("Accuracy:", accuracy)
    print("AUC:", auc_score)

    labels = ['0', '1']
    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()
# Out:
# Accuracy: 0.7434966727162734
# AUC: 0.6517615647746708
# Accuracy: 0.764065335753176
# AUC: 0.6345561035758324

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have X_train_resampled, y_train_resampled, X_test, y_test defined

classifiers = [
    RandomForestClassifier(n_estimators=50, random_state=0),
    AdaBoostClassifier(n_estimators=50, random_state=0)
]

# Create an ensemble model using VotingClassifier
ensemble_clf = VotingClassifier(estimators=[('rf', classifiers[0]), ('ada', classifiers[1])], voting='hard')

ensemble_clf.fit(X_train_resampled, y_train_resampled)
y_pred = ensemble_clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print("Accuracy:", accuracy)
print("AUC:", auc_score)

labels = ['0', '1']
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.8197217180883243
# AUC: 0.6391849966190685

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import GridSearchCV
import pandas as pd

# Assuming you have X_train_resampled, y_train_resampled, X_test, y_test defined

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

# Initialize the classifier
clf = RandomForestClassifier(random_state=0)

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(clf, param_grid, cv=5)
grid_search.fit(X_train_resampled, y_train_resampled)

# Get the best classifier with tuned hyperparameters
clf_best = grid_search.best_estimator_

# Make predictions
y_pred = clf_best.predict(X_test)
y_pred_prob = clf_best.predict_proba(X_test)

# Adjust the threshold for classification
threshold = 0.3
y_pred_adjusted = (y_pred_prob[:, 1] > threshold).astype(int)

accuracy = accuracy_score(y_test, y_pred_adjusted)
auc_score = roc_auc_score(y_test, y_pred_adjusted)
cm = confusion_matrix(y_test, y_pred_adjusted)

print("Accuracy:", accuracy)
print("AUC:", auc_score)

labels = ['0', '1']
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_adjusted)

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Print the confusion matrix as a table
print(cm_df)
# Out:
# Accuracy: 0.45447670901391407
# AUC: 0.6231454596078119
#           Predicted 0  Predicted 1
# Actual 0         2906         3582
# Actual 1           25           99

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
import pandas as pd

# Assuming you have X_train_resampled, y_train_resampled, X_test, y_test defined

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

# Initialize the classifier
clf = RandomForestClassifier(random_state=0)

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(clf, param_grid, cv=5)
grid_search.fit(X_train_resampled, y_train_resampled)

# Get the best classifier with tuned hyperparameters
clf_best = grid_search.best_estimator_

# Feature selection using SelectFromModel
sfm = SelectFromModel(clf_best, threshold='median')
X_train_selected = sfm.fit_transform(X_train_resampled, y_train_resampled)
X_test_selected = sfm.transform(X_test)

# Fit the classifier on the selected features
clf_best.fit(X_train_selected, y_train_resampled)

# Make predictions
y_pred = clf_best.predict(X_test_selected)
y_pred_prob = clf_best.predict_proba(X_test_selected)

# Adjust the threshold for classification
threshold = 0.3
y_pred_adjusted = (y_pred_prob[:, 1] > threshold).astype(int)

accuracy = accuracy_score(y_test, y_pred_adjusted)
auc_score = roc_auc_score(y_test, y_pred_adjusted)
cm = confusion_matrix(y_test, y_pred_adjusted)

print("Accuracy:", accuracy)
print("AUC:", auc_score)

labels = ['0', '1']
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_adjusted)

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Print the confusion matrix as a table
print(cm_df)
# Out:
# Accuracy: 0.4165154264972777
# AUC: 0.6196228272542859
#           Predicted 0  Predicted 1
# Actual 0         2651         3837
# Actual 1           21          103

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
import pandas as pd

# Assuming you have X_train_resampled, y_train_resampled, X_test, y_test defined

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

# Initialize the classifier
clf = RandomForestClassifier(random_state=0, class_weight='balanced')

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(clf, param_grid, cv=5)
grid_search.fit(X_train_resampled, y_train_resampled)

# Get the best classifier with tuned hyperparameters
clf_best = grid_search.best_estimator_

# Feature selection using SelectFromModel
sfm = SelectFromModel(clf_best, threshold='median')
X_train_selected = sfm.fit_transform(X_train_resampled, y_train_resampled)
X_test_selected = sfm.transform(X_test)

# Fit the classifier on the selected features
clf_best.fit(X_train_selected, y_train_resampled)

# Make predictions
y_pred = clf_best.predict(X_test_selected)
y_pred_prob = clf_best.predict_proba(X_test_selected)

# Adjust the threshold for classification
threshold = 0.7  # Adjust the threshold as desired
y_pred_adjusted = (y_pred_prob[:, 1] > threshold).astype(int)

accuracy = accuracy_score(y_test, y_pred_adjusted)
auc_score = roc_auc_score(y_test, y_pred_adjusted)
cm = confusion_matrix(y_test, y_pred_adjusted)

print("Accuracy:", accuracy)
print("AUC:", auc_score)

labels = ['0', '1']
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_adjusted)

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Print the confusion matrix as a table
print(cm_df)
# Out:
# Accuracy: 0.9153055051421658
# AUC: 0.5890104808877928
#           Predicted 0  Predicted 1
# Actual 0         6021          467
# Actual 1           93           31

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
import pandas as pd

# Assuming you have X_train_resampled, y_train_resampled, X_test, y_test defined

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

# Initialize the classifier
clf = RandomForestClassifier(random_state=0, class_weight='balanced')

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(clf, param_grid, cv=5)
grid_search.fit(X_train_resampled, y_train_resampled)

# Get the best classifier with tuned hyperparameters
clf_best = grid_search.best_estimator_

# Feature selection using SelectFromModel
sfm = SelectFromModel(clf_best, threshold='median')
X_train_selected = sfm.fit_transform(X_train_resampled, y_train_resampled)
X_test_selected = sfm.transform(X_test)

# Fit the classifier on the selected features
clf_best.fit(X_train_selected, y_train_resampled)

# Make predictions
y_pred = clf_best.predict(X_test_selected)
y_pred_prob = clf_best.predict_proba(X_test_selected)

# Adjust the threshold for classification
threshold = 0.2  # Decreasing the threshold
y_pred_adjusted = (y_pred_prob[:, 1] > threshold).astype(int)

accuracy = accuracy_score(y_test, y_pred_adjusted)
auc_score = roc_auc_score(y_test, y_pred_adjusted)
cm = confusion_matrix(y_test, y_pred_adjusted)

print("Accuracy:", accuracy)
print("AUC:", auc_score)

labels = ['0', '1']
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_adjusted)

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Print the confusion matrix as a table
print(cm_df)
# Out:
# Accuracy: 0.27223230490018147
# AUC: 0.5777440237062965
#           Predicted 0  Predicted 1
# Actual 0         1689         4799
# Actual 1           13          111

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures

# Assuming you have df_for_predict dataframe

# Feature engineering - Polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_train_poly = poly.fit_transform(X_train_resampled)
X_test_poly = poly.transform(X_test)

# Get polynomial feature names
feature_names = X_train_resampled.columns
poly_feature_names = poly.get_feature_names_out(feature_names)

# Create dataframes for the polynomial features
X_train_poly_df = pd.DataFrame(X_train_poly, columns=poly_feature_names)
X_test_poly_df = pd.DataFrame(X_test_poly, columns=poly_feature_names)

# Concatenate the polynomial features with the original features
X_train_features = pd.concat([X_train_resampled, X_train_poly_df], axis=1)

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)
(df_for_predict.corr()).style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_e8e93_row0_col0, #T_e8e93_row1_col1, #T_e8e93_row2_col2, #T_e8e93_row3_col3, #T_e8e93_row4_col4, #T_e8e93_row5_col5, #T_e8e93_row6_col6, #T_e8e93_row7_col7, #T_e8e93_row8_col8, #T_e8e93_row9_col9 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_e8e93_row0_col1, #T_e8e93_row0_col8, #T_e8e93_row0_col9, #T_e8e93_row1_col0, #T_e8e93_row3_col6, #T_e8e93_row6_col2, #T_e8e93_row6_col3, #T_e8e93_row6_col4, #T_e8e93_row6_col5, #T_e8e93_row6_col7 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_e8e93_row0_col2, #T_e8e93_row4_col2 {
#   background-color: #bfdebf;
#   color: #000000;
# }
# #T_e8e93_row0_col3 {
#   background-color: #8bc48b;
#   color: #000000;
# }
# #T_e8e93_row0_col4, #T_e8e93_row2_col4 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_e8e93_row0_col5, #T_e8e93_row3_col2 {
#   background-color: #d7e9d7;
#   color: #000000;
# }
# #T_e8e93_row0_col6 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_e8e93_row0_col7, #T_e8e93_row4_col6, #T_e8e93_row5_col3 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_e8e93_row1_col2 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_e8e93_row1_col3 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_e8e93_row1_col4 {
#   background-color: #daebda;
#   color: #000000;
# }
# #T_e8e93_row1_col5, #T_e8e93_row7_col2 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_e8e93_row1_col6 {
#   background-color: #89c389;
#   color: #000000;
# }
# #T_e8e93_row1_col7 {
#   background-color: #add5ad;
#   color: #000000;
# }
# #T_e8e93_row1_col8 {
#   background-color: #bddcbd;
#   color: #000000;
# }
# #T_e8e93_row1_col9, #T_e8e93_row7_col5 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_e8e93_row2_col0, #T_e8e93_row5_col0 {
#   background-color: #78bb78;
#   color: #f1f1f1;
# }
# #T_e8e93_row2_col1, #T_e8e93_row5_col1 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_e8e93_row2_col3, #T_e8e93_row4_col7 {
#   background-color: #a8d2a8;
#   color: #000000;
# }
# #T_e8e93_row2_col5 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_e8e93_row2_col6 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_e8e93_row2_col7 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_e8e93_row2_col8 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_e8e93_row2_col9, #T_e8e93_row5_col8, #T_e8e93_row8_col5 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_e8e93_row3_col0, #T_e8e93_row7_col0 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_e8e93_row3_col1, #T_e8e93_row7_col1 {
#   background-color: #7bbc7b;
#   color: #000000;
# }
# #T_e8e93_row3_col4, #T_e8e93_row5_col9 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_e8e93_row3_col5, #T_e8e93_row7_col9, #T_e8e93_row8_col4 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_e8e93_row3_col7 {
#   background-color: #cde5cd;
#   color: #000000;
# }
# #T_e8e93_row3_col8 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_e8e93_row3_col9 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_e8e93_row4_col0 {
#   background-color: #77ba77;
#   color: #f1f1f1;
# }
# #T_e8e93_row4_col1 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_e8e93_row4_col3 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_e8e93_row4_col5 {
#   background-color: #d5e9d5;
#   color: #000000;
# }
# #T_e8e93_row4_col8 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_e8e93_row4_col9, #T_e8e93_row7_col4 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_e8e93_row5_col2, #T_e8e93_row9_col8 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_e8e93_row5_col4 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_e8e93_row5_col6 {
#   background-color: #a4d0a4;
#   color: #000000;
# }
# #T_e8e93_row5_col7 {
#   background-color: #acd4ac;
#   color: #000000;
# }
# #T_e8e93_row6_col0 {
#   background-color: #7dbd7d;
#   color: #000000;
# }
# #T_e8e93_row6_col1 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_e8e93_row6_col8, #T_e8e93_row7_col8 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_e8e93_row6_col9 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_e8e93_row7_col3 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_e8e93_row7_col6 {
#   background-color: #d3e7d3;
#   color: #000000;
# }
# #T_e8e93_row8_col0 {
#   background-color: #83c083;
#   color: #000000;
# }
# #T_e8e93_row8_col1 {
#   background-color: #68b368;
#   color: #f1f1f1;
# }
# #T_e8e93_row8_col2 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_e8e93_row8_col3 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_e8e93_row8_col6, #T_e8e93_row9_col3 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_e8e93_row8_col7 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_e8e93_row8_col9 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_e8e93_row9_col0 {
#   background-color: #78bb78;
#   color: #000000;
# }
# #T_e8e93_row9_col1 {
#   background-color: #72b872;
#   color: #f1f1f1;
# }
# #T_e8e93_row9_col2 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_e8e93_row9_col4 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_e8e93_row9_col5 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_e8e93_row9_col6 {
#   background-color: #96c996;
#   color: #000000;
# }
# #T_e8e93_row9_col7 {
#   background-color: #a2cfa2;
#   color: #000000;
# }
# </style>
# <table id="T_e8e93" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8e93_level0_col0" class="col_heading level0 col0" >sex_female</th>
#       <th id="T_e8e93_level0_col1" class="col_heading level0 col1" >sex_male</th>
#       <th id="T_e8e93_level0_col2" class="col_heading level0 col2" >anatom_site_general_challenge_head/neck</th>
#       <th id="T_e8e93_level0_col3" class="col_heading level0 col3" >anatom_site_general_challenge_lower extremity</th>
#       <th id="T_e8e93_level0_col4" class="col_heading level0 col4" >anatom_site_general_challenge_oral/genital</th>
#       <th id="T_e8e93_level0_col5" class="col_heading level0 col5" >anatom_site_general_challenge_palms/soles</th>
#       <th id="T_e8e93_level0_col6" class="col_heading level0 col6" >anatom_site_general_challenge_torso</th>
#       <th id="T_e8e93_level0_col7" class="col_heading level0 col7" >anatom_site_general_challenge_upper extremity</th>
#       <th id="T_e8e93_level0_col8" class="col_heading level0 col8" >age_approx</th>
#       <th id="T_e8e93_level0_col9" class="col_heading level0 col9" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8e93_level0_row0" class="row_heading level0 row0" >sex_female</th>
#       <td id="T_e8e93_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e8e93_row0_col1" class="data row0 col1" >-1.000000</td>
#       <td id="T_e8e93_row0_col2" class="data row0 col2" >-0.015755</td>
#       <td id="T_e8e93_row0_col3" class="data row0 col3" >0.054159</td>
#       <td id="T_e8e93_row0_col4" class="data row0 col4" >-0.014787</td>
#       <td id="T_e8e93_row0_col5" class="data row0 col5" >-0.017291</td>
#       <td id="T_e8e93_row0_col6" class="data row0 col6" >-0.066969</td>
#       <td id="T_e8e93_row0_col7" class="data row0 col7" >0.048844</td>
#       <td id="T_e8e93_row0_col8" class="data row0 col8" >-0.109827</td>
#       <td id="T_e8e93_row0_col9" class="data row0 col9" >-0.028612</td>
#     </tr>
#     <tr>
#       <th id="T_e8e93_level0_row1" class="row_heading level0 row1" >sex_male</th>
#       <td id="T_e8e93_row1_col0" class="data row1 col0" >-1.000000</td>
#       <td id="T_e8e93_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e8e93_row1_col2" class="data row1 col2" >0.015755</td>
#       <td id="T_e8e93_row1_col3" class="data row1 col3" >-0.054159</td>
#       <td id="T_e8e93_row1_col4" class="data row1 col4" >0.014787</td>
#       <td id="T_e8e93_row1_col5" class="data row1 col5" >0.017291</td>
#       <td id="T_e8e93_row1_col6" class="data row1 col6" >0.066969</td>
#       <td id="T_e8e93_row1_col7" class="data row1 col7" >-0.048844</td>
#       <td id="T_e8e93_row1_col8" class="data row1 col8" >0.109827</td>
#       <td id="T_e8e93_row1_col9" class="data row1 col9" >0.028612</td>
#     </tr>
#     <tr>
#       <th id="T_e8e93_level0_row2" class="row_heading level0 row2" >anatom_site_general_challenge_head/neck</th>
#       <
